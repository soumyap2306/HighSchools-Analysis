# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/soumya/Desktop/SEM2/Big Data/project/School Data- Redefined.csv')
data
# Out:
#                      School NAme     City  Zip Code 2022 Student Enrollments  \
# 0       ArizoNA Lutheran Academy  Phoenix   85041.0                      192
# 1    ArizoNA Preparatory Academy  Phoenix   85037.0                      123
# 2    ArizoNA School For The Arts  Phoenix   85004.0                      832
# 3        ArizoNA Virtual Academy  Phoenix   85004.0                     7647
# 4        Asdb/phoenix Day school  Phoenix   85021.0                      242
# ..                           ...      ...       ...                      ...
# 474                          NaN      NaN       NaN                      NaN
# 475                          NaN      NaN       NaN                      NaN
# 476                          NaN      NaN       NaN                      NaN
# 477                          NaN      NaN       NaN                      NaN
# 478                          NaN      NaN       NaN                      NaN
#
# ...

# %%
print("counting the missing values in each row ")
print(data.isna().sum(axis=1))
# Out:
# counting the missing values in each row
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 474    15
# 475    15
# 476    15
# 477    15
# 478    15
# Length: 479, dtype: int64

# %%
print("\ncounting the missing values in each column:")
print(data.isna().sum())
# Out:
# counting the missing values in each column:
# School NAme                  10
# City                         10
# Zip Code                     10
# 2022 Student Enrollments     21
# AP Classes?                  89
# Math Score                  136
# English Score               154
# NAtioNAl Rank               148
# AZ Rank                     113
# Racial%-White                30
# Racial%-Black                34
# Racial%-NAtive               60
# Racial%-Hispanic             29
# Racial%-Asian                46
# Racial%-Other                44
# dtype: int64

# %%
columns_to_delete=['Math Score','English Score','NAtioNAl Rank','AZ Rank','Racial%-NAtive']
data =data.drop(columns=columns_to_delete)

# %%
data
# Out:
#                      School NAme     City  Zip Code 2022 Student Enrollments  \
# 0       ArizoNA Lutheran Academy  Phoenix   85041.0                      192
# 1    ArizoNA Preparatory Academy  Phoenix   85037.0                      123
# 2    ArizoNA School For The Arts  Phoenix   85004.0                      832
# 3        ArizoNA Virtual Academy  Phoenix   85004.0                     7647
# 4        Asdb/phoenix Day school  Phoenix   85021.0                      242
# ..                           ...      ...       ...                      ...
# 474                          NaN      NaN       NaN                      NaN
# 475                          NaN      NaN       NaN                      NaN
# 476                          NaN      NaN       NaN                      NaN
# 477                          NaN      NaN       NaN                      NaN
# 478                          NaN      NaN       NaN                      NaN
#
# ...

# %%
data_new=data.dropna()

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix   85041.0
# 1           ArizoNA Preparatory Academy   Phoenix   85037.0
# 2           ArizoNA School For The Arts   Phoenix   85004.0
# 3               ArizoNA Virtual Academy   Phoenix   85004.0
# 4               Asdb/phoenix Day school   Phoenix   85021.0
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale   85306.0
# 464                 Deer Valley Academy  Glendale   85308.0
# 465             Deer Valley High School  Glendale   85308.0
# 466  Desert Heights Preparatory Academy  Glendale   85308.0
# 467            Desert Sky Middle School  Glendale   85308.0
#
#     2022 Student Enrollments AP Classes? Racial%-White Racial%-Black  \
# 0                        192         Yes            57             6
# 1                        123         Yes            12            11
# ...

# %%
print(data_new.isna().sum(axis=1))
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 463    0
# 464    0
# 465    0
# 466    0
# 467    0
# Length: 359, dtype: int64

# %%
print(data.isna().sum())
# Out:
# School NAme                 10
# City                        10
# Zip Code                    10
# 2022 Student Enrollments    21
# AP Classes?                 89
# Racial%-White               30
# Racial%-Black               34
# Racial%-Hispanic            29
# Racial%-Asian               46
# Racial%-Other               44
# dtype: int64

# %%
columns_to_delete=['AP Classes?','Racial%-Asian','Racial%-Other']
data_new =data_new.drop(columns=columns_to_delete)

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix   85041.0
# 1           ArizoNA Preparatory Academy   Phoenix   85037.0
# 2           ArizoNA School For The Arts   Phoenix   85004.0
# 3               ArizoNA Virtual Academy   Phoenix   85004.0
# 4               Asdb/phoenix Day school   Phoenix   85021.0
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale   85306.0
# 464                 Deer Valley Academy  Glendale   85308.0
# 465             Deer Valley High School  Glendale   85308.0
# 466  Desert Heights Preparatory Academy  Glendale   85308.0
# 467            Desert Sky Middle School  Glendale   85308.0
#
#     2022 Student Enrollments Racial%-White Racial%-Black Racial%-Hispanic
# 0                        192            57             6               15
# 1                        123            12            11               71
# ...

# %%
print(data.isna().sum())
# Out:
# School NAme                 10
# City                        10
# Zip Code                    10
# 2022 Student Enrollments    21
# Racial%-White               30
# Racial%-Black               34
# Racial%-Hispanic            29
# dtype: int64

# %%
print(data_new.isna().sum(axis=1))
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 463    0
# 464    0
# 465    0
# 466    0
# 467    0
# Length: 359, dtype: int64

# %%
data_new = data_new.drop_duplicates(subset=['School Name', 'Zip Code'], keep='first')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/3402728433.py in <module>
# ----> 1 data_new = data_new.drop_duplicates(subset=['School Name', 'Zip Code'], keep='first')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6123         inplace = validate_bool_kwarg(inplace, "inplace")
#    6124         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6125         duplicated = self.duplicated(subset, keep=keep)
#    6126
# ...

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix   85041.0
# 1           ArizoNA Preparatory Academy   Phoenix   85037.0
# 2           ArizoNA School For The Arts   Phoenix   85004.0
# 3               ArizoNA Virtual Academy   Phoenix   85004.0
# 4               Asdb/phoenix Day school   Phoenix   85021.0
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale   85306.0
# 464                 Deer Valley Academy  Glendale   85308.0
# 465             Deer Valley High School  Glendale   85308.0
# 466  Desert Heights Preparatory Academy  Glendale   85308.0
# 467            Desert Sky Middle School  Glendale   85308.0
#
#     2022 Student Enrollments Racial%-White Racial%-Black Racial%-Hispanic
# 0                        192            57             6               15
# 1                        123            12            11               71
# ...

# %%
data_new = data_new.drop_duplicates(subset=['School NAme', 'Zip Code'], keep='first')

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix   85041.0
# 1           ArizoNA Preparatory Academy   Phoenix   85037.0
# 2           ArizoNA School For The Arts   Phoenix   85004.0
# 3               ArizoNA Virtual Academy   Phoenix   85004.0
# 4               Asdb/phoenix Day school   Phoenix   85021.0
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale   85306.0
# 464                 Deer Valley Academy  Glendale   85308.0
# 465             Deer Valley High School  Glendale   85308.0
# 466  Desert Heights Preparatory Academy  Glendale   85308.0
# 467            Desert Sky Middle School  Glendale   85308.0
#
#     2022 Student Enrollments Racial%-White Racial%-Black Racial%-Hispanic
# 0                        192            57             6               15
# 1                        123            12            11               71
# ...

# %%
row_maxnan = data_new.isna().sum(axis=1).idxmax()
print(data_new.loc[row_maxnan])
# Out:
# School NAme                 ArizoNA Lutheran Academy
# City                                         Phoenix
# Zip Code                                     85041.0
# 2022 Student Enrollments                         192
# Racial%-White                                     57
# Racial%-Black                                      6
# Racial%-Hispanic                                  15
# Name: 0, dtype: object

# %%
data_new['Zip Code'] = data_new['Zip Code'].astype(int)
# Out:
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/3012006718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new['Zip Code'] = data_new['Zip Code'].astype(int)

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black Racial%-Hispanic
# 0                        192            57             6               15
# 1                        123            12            11               71
# ...

# %%
for column in data_new.columns:
    if pd.api.types.is_numeric_dtype(data_new[column]):
       data_new[column] = pd.to_numeric(data_new[column].replace('[\$, %]', '', regex=True), errors='coerce')
# Out:
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/577321572.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new[column] = pd.to_numeric(data_new[column].replace('[\$, %]', '', regex=True), errors='coerce')

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black Racial%-Hispanic
# 0                        192            57             6               15
# 1                        123            12            11               71
# ...

# %%
# Use .loc to avoid the SettingWithCopyWarning
data_new.loc[:, column] = pd.to_numeric(data_new[column].replace('[\$, %]', '', regex=True), errors='coerce')
# Out:
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/2650738063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new.loc[:, column] = pd.to_numeric(data_new[column].replace('[\$, %]', '', regex=True), errors='coerce')

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black  Racial%-Hispanic
# 0                        192            57             6              15.0
# 1                        123            12            11              71.0
# ...

# %%
for column in data_new.columns:
    if pd.api.types.is_numeric_dtype(data_new[column]):
        data_new.loc[:, column] = pd.to_numeric(data_new[column].replace('[\$, %]', '', regex=True), errors='coerce')
# Out:
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/805041624.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new.loc[:, column] = pd.to_numeric(data_new[column].replace('[\$, %]', '', regex=True), errors='coerce')

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black  Racial%-Hispanic
# 0                        192            57             6              15.0
# 1                        123            12            11              71.0
# ...

# %%
data_new.loc[:, column] = pd.to_numeric(data_new['Racial%-Black'].replace('[\$, %]', '', regex=True), errors='coerce')
# Out:
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/1096682543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new.loc[:, column] = pd.to_numeric(data_new['Racial%-Black'].replace('[\$, %]', '', regex=True), errors='coerce')

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black  Racial%-Hispanic
# 0                        192            57             6               6.0
# 1                        123            12            11              11.0
# ...

# %%
data_new['Racial%-White'] = data_new['Racial%-White'].str.replace('%','')
data_new['Racial%-Black'] = data_new['Racial%-Black'].str.replace('%','')
# Out:
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/4261820127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new['Racial%-White'] = data_new['Racial%-White'].str.replace('%','')
# /var/folders/yd/jlxh65014sl1yfx6_f_p1fsh0000gn/T/ipykernel_1386/4261820127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new['Racial%-Black'] = data_new['Racial%-Black'].str.replace('%','')

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black  Racial%-Hispanic
# 0                        192            57             6               6.0
# 1                        123            12            11              11.0
# ...

# %%
data_new
# Out:
#                             School NAme      City  Zip Code  \
# 0              ArizoNA Lutheran Academy   Phoenix     85041
# 1           ArizoNA Preparatory Academy   Phoenix     85037
# 2           ArizoNA School For The Arts   Phoenix     85004
# 3               ArizoNA Virtual Academy   Phoenix     85004
# 4               Asdb/phoenix Day school   Phoenix     85021
# ..                                  ...       ...       ...
# 463                    Sunflower School  Glendale     85306
# 464                 Deer Valley Academy  Glendale     85308
# 465             Deer Valley High School  Glendale     85308
# 466  Desert Heights Preparatory Academy  Glendale     85308
# 467            Desert Sky Middle School  Glendale     85308
#
#     2022 Student Enrollments Racial%-White Racial%-Black  Racial%-Hispanic
# 0                        192            57             6               6.0
# 1                        123            12            11              11.0
# ...

# %%
#DATA Transformation

# %%
Datanew_final=data_new[['Racial%-White','Racial%-Black','Racial%-Hispanic','2022 Student Enrollments']]

# %%
Datanew_final
# Out:
#     Racial%-White Racial%-Black  Racial%-Hispanic 2022 Student Enrollments
# 0              57             6               6.0                      192
# 1              12            11              11.0                      123
# 2              63             4               4.0                      832
# 3              69             6               6.0                     7647
# 4              16             7               7.0                      242
# ..            ...           ...               ...                      ...
# 463            35           7.5               7.5                       40
# 464         33.30         16.70              16.7                    1,568
# 465         55.20          5.90               5.9                    1,420
# 466         56.20          7.20               7.2                      511
# 467         54.30          4.30               4.3                      761
#
# [327 rows x 4 columns]
